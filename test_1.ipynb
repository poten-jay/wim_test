# %%
pip install jupyter
# Out:
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.4.0-py3-none-any.whl (121 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
# Requirement already satisfied: ipykernel in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter) (6.15.0)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.2-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.2.9-py3-none-any.whl (274 kB)
# Collecting notebook
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (7.3.4)
# Requirement already satisfied: nest-asyncio in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: packaging in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (23.0)
# Requirement already satisfied: tornado>=6.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: psutil in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: appnope in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: pyzmq>=17 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (23.2.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (8.11.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel->jupyter) (1.5.1)
# Collecting widgetsnbextension~=4.0
#   Using cached widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-console->jupyter) (5.2.0)
# Requirement already satisfied: pygments in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.14.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.38)
# Collecting jinja2>=3.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting nbformat>=5.1
#   Using cached nbformat-5.7.3-py3-none-any.whl (78 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-macosx_10_9_universal2.whl (17 kB)
# Collecting importlib-metadata>=3.6
#   Using cached importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting mistune<3,>=2.0.3
#   Using cached mistune-2.0.5-py2.py3-none-any.whl (24 kB)
# Collecting bleach
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.5.2-py3-none-any.whl (10.0 MB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.16.0-py3-none-any.whl (122 kB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.3.0-py3-none-any.whl (83 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pickleshare in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: decorator in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: backcall in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: entrypoints in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter) (3.0.0)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.3.0-py3-none-any.whl (365 kB)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.16.3-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: wcwidth in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.6)
# Requirement already satisfied: ptyprocess in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp38-cp38-macosx_10_9_universal2.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 3.8 MB/s eta 0:00:00
# Collecting attrs>=17.4.0
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-25.0.0-cp38-cp38-macosx_10_15_universal2.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting tornado>=6.1
#   Using cached tornado-6.2-cp37-abi3-macosx_10_9_universal2.whl (421 kB)
# Collecting anyio>=3.1.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting jupyter-client>=6.1.12
#   Using cached jupyter_client-8.0.3-py3-none-any.whl (102 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Collecting cffi>=1.0.1
#   Downloading cffi-1.15.1.tar.gz (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.5/508.5 kB 10.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: executing>=1.2.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting idna>=2.8
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0.tar.gz (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 11.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Building wheels for collected packages: cffi, pyyaml
#   Building wheel for cffi (setup.py) ... done
#   Created wheel for cffi: filename=cffi-1.15.1-cp38-cp38-macosx_11_0_arm64.whl size=175423 sha256=76ede535299ad67e688901026a1ab3887433fd94181501c20b8738e65aac5a27
#   Stored in directory: /Users/jay/Library/Caches/pip/wheels/4f/6c/1c/87e97bb9c55afbf66881d37eed21c108b012c29105af6be450
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-6.0-cp38-cp38-macosx_11_0_arm64.whl size=45335 sha256=d5064458861d0fcc339e4c89fe36a198bfdcc6cedbd1d66800ac4e1e6702d236
#   Stored in directory: /Users/jay/Library/Caches/pip/wheels/52/84/66/50912fd7bf1639a31758e40bd4312602e104a8eca1e0da9645
# Successfully built cffi pyyaml
# Installing collected packages: webencodings, Send2Trash, mistune, ipython-genutils, fastjsonschema, zipp, widgetsnbextension, websocket-client, webcolors, uri-template, tornado, tinycss2, soupsieve, sniffio, rfc3986-validator, rfc3339-validator, qtpy, pyzmq, pyyaml, python-json-logger, pyrsistent, pycparser, prometheus-client, pkgutil-resolve-name, pandocfilters, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, idna, fqdn, defusedxml, bleach, attrs, terminado, jinja2, importlib-resources, importlib-metadata, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, jupyter-client, jsonschema, isoduration, argon2-cffi-bindings, nbformat, argon2-cffi, qtconsole, nbclient, jupyter-events, jupyter-console, ipywidgets, nbconvert, jupyter-server, notebook-shim, nbclassic, notebook, jupyter
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.3.4
#     Uninstalling jupyter-client-7.3.4:
#       Successfully uninstalled jupyter-client-7.3.4
# Successfully installed Send2Trash-1.8.0 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 attrs-22.2.0 beautifulsoup4-4.11.2 bleach-6.0.0 cffi-1.15.1 defusedxml-0.7.1 fastjsonschema-2.16.3 fqdn-1.5.1 idna-3.4 importlib-metadata-6.0.0 importlib-resources-5.12.0 ipython-genutils-0.2.0 ipywidgets-8.0.4 isoduration-20.11.0 jinja2-3.1.2 jsonpointer-2.3 jsonschema-4.17.3 jupyter-1.0.0 jupyter-client-8.0.3 jupyter-console-6.6.2 jupyter-events-0.6.3 jupyter-server-2.3.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.5 markupsafe-2.1.2 mistune-2.0.5 nbclassic-0.5.2 nbclient-0.7.2 nbconvert-7.2.9 nbformat-5.7.3 notebook-6.5.2 notebook-shim-0.2.2 pandocfilters-1.5.0 pkgutil-resolve-name-1.3.10 prometheus-client-0.16.0 pycparser-2.21 pyrsistent-0.19.3 python-json-logger-2.0.7 pyyaml-6.0 pyzmq-25.0.0 qtconsole-5.4.0 qtpy-2.3.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 sniffio-1.3.0 soupsieve-2.4 terminado-0.17.1 tinycss2-1.2.1 tornado-6.2 uri-template-1.2.0 webcolors-1.12 webencodings-0.5.1 websocket-client-1.5.1 widgetsnbextension-4.0.5 zipp-3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (6.15.0)
# Requirement already satisfied: nest-asyncio in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: appnope in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: psutil in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: packaging in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (23.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (8.11.0)
# Requirement already satisfied: tornado>=6.1 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (8.0.3)
# Requirement already satisfied: pyzmq>=17 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipykernel) (25.0.0)
# Requirement already satisfied: pexpect>4.3 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: backcall in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: decorator in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: pickleshare in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (2.14.0)
# Requirement already satisfied: stack-data in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (5.2.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel) (3.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: pure-eval in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/jay/opt/anaconda3/envs/test1/lib/python3.8/site-packages (22.3.1)
# Collecting pip
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m ipykernel install --user --name test1 --display-name "test1"
# Out:
#   Cell In[6], line 1
#     python -m ipykernel install --user --name test1 --display-name "test1"
#               ^
# SyntaxError: invalid syntax

# %%
pip install jupyter



python -m ipykernel install --user --name [가상환경 이름] --display-name "[jupyter에 표시될 kernel의 이름]"+

python -m ipykernel install --user --name cuda --display-name "CUDA"

# %%
piykernl -v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 piykernl -v
#
# NameError: name 'piykernl' is not defined
